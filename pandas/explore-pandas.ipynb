# %%
from pandas import DataFrame
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
unemployment_data = pd.read_csv('unemployment.csv')
poverty_data = pd.read_csv('povertyData.csv')
pop_data = pd.read_csv('population_estimates.csv')
educ_data = pd.read_csv('educ_data.csv')

# %%
#pop_data
# educ_data
poverty_data
# unemployment_data
# Out:
#          2  FIPStxt State           Area_Name  \
# 0        3        0    US       United States
# 1        4     1000    AL             Alabama
# 2        5     1001    AL      Autauga County
# 3        6     1003    AL      Baldwin County
# 4        7     1005    AL      Barbour County
# 5        8     1007    AL         Bibb County
# 6        9     1009    AL       Blount County
# 7       10     1011    AL      Bullock County
# 8       11     1013    AL       Butler County
# 9       12     1015    AL      Calhoun County
# 10      13     1017    AL     Chambers County
# 11      14     1019    AL     Cherokee County
# 12      15     1021    AL      Chilton County
# 13      16     1023    AL      Choctaw County
# 14      17     1025    AL       Clarke County
# 15      18     1027    AL         Clay County
# 16      19     1029    AL     Cleburne County
# 17      20     1031    AL       Coffee County
# 18      21     1033    AL      Colbert County
# ...

# %%
#To access a single column

poverty_data.Area_Name
# Out:
# 0            United States
# 1                  Alabama
# 2           Autauga County
# 3           Baldwin County
# 4           Barbour County
# 5              Bibb County
# 6            Blount County
# 7           Bullock County
# 8            Butler County
# 9           Calhoun County
# 10         Chambers County
# 11         Cherokee County
# 12          Chilton County
# 13          Choctaw County
# 14           Clarke County
# 15             Clay County
# 16         Cleburne County
# 17           Coffee County
# 18          Colbert County
# 19          Conecuh County
# 20            Coosa County
# 21        Covington County
# 22         Crenshaw County
# 23          Cullman County
# 24             Dale County
# 25           Dallas County
# 26           DeKalb County
# 27           Elmore County
# 28         Escambia County
# 29           Etowah County
#                ...
# 3164     Washington County
# 3165       Waukesha County
# 3166        Waupaca County
# ...

# %%
#indexing
poverty_data.loc[1, 'Area_Name']
# Out:
# 'Alabama'

# %%
#iloc indexing
poverty_data.iloc[1, [2,6]]
# Out:
# State                               AL
# Rural-urban_Continuum_Code_2013    NaN
# Name: 1, dtype: object

# %%
poverty_data.head()
# Out:
#    2  FIPStxt State       Area_Name  Rural-urban_Continuum_Code_2003  \
# 0  3        0    US   United States                              NaN
# 1  4     1000    AL         Alabama                              NaN
# 2  5     1001    AL  Autauga County                              2.0
# 3  6     1003    AL  Baldwin County                              4.0
# 4  7     1005    AL  Barbour County                              6.0
#
#    Urban_Influence_Code_2003  Rural-urban_Continuum_Code_2013  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        2.0                              2.0
# 3                        5.0                              3.0
# 4                        6.0                              6.0
#
#    Urban_Influence_Code_2013  POVALL_2017  CI90LBAll_2017  ...  \
# 0                        NaN   42583651.0      42342619.0  ...
# ...

# %%
#get the first 10 rows
poverty_data.iloc[:10]
# Out:
#     2  FIPStxt State       Area_Name  Rural-urban_Continuum_Code_2003  \
# 0   3        0    US   United States                              NaN
# 1   4     1000    AL         Alabama                              NaN
# 2   5     1001    AL  Autauga County                              2.0
# 3   6     1003    AL  Baldwin County                              4.0
# 4   7     1005    AL  Barbour County                              6.0
# 5   8     1007    AL     Bibb County                              1.0
# 6   9     1009    AL   Blount County                              1.0
# 7  10     1011    AL  Bullock County                              6.0
# 8  11     1013    AL   Butler County                              6.0
# 9  12     1015    AL  Calhoun County                              3.0
#
#    Urban_Influence_Code_2003  Rural-urban_Continuum_Code_2013  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# ...
